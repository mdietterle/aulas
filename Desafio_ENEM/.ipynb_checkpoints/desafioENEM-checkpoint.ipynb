# %%
import pandas as pd
import time
import psutil
import numpy as np
import multiprocessing as mp

num_cores = mp.cpu_count()
print("Este processador tem ",num_cores,"nucleos. Uso da memória:",psutil.virtual_memory())

tamanho_bloco = 1e6 #1 milhão
start_time = time.time()
i=1
check=0
file="C:\\Users\\Martim\\Downloads\\Compressed\\microdados_enem2016\\microdados_enem_2016.csv"
indice=['NU_INSCRICAO']
colunas=['NU_INSCRICAO','TP_PRESENCA_CN','TP_PRESENCA_CH','TP_PRESENCA_LC','TP_PRESENCA_MT','NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','TP_STATUS_REDACAO','NU_NOTA_REDACAO']
print("Iniciando leitura e filtragem dos dados... ")
print("Cada loop lê 1 milhão de linhas do arquivo...")
print("------------------------------------------------------------------------------")
for chunk in pd.read_csv(file,chunksize=tamanho_bloco,index_col=None,encoding="latin-1",usecols=colunas,delimiter=";"):
	chunk=chunk.dropna(subset=colunas)
	if(i==1):
		chunk[chunk.TP_PRESENCA_CN == 1]
		chunk[chunk.TP_PRESENCA_CH == 1]
		chunk[chunk.TP_PRESENCA_LC == 1]
		chunk[chunk.TP_PRESENCA_MT == 1]
		chunk[chunk.TP_STATUS_REDACAO == 1]
		result = chunk
		print("Numero de linhas  úteis, já descartadas provas eliminadas: ",chunk.shape[0])#result.shape[0])
		print("Loop ",i,"demorou %s segundos..." % (time.time() - start_time))
		i+=1
		chunk['teste']=((chunk.NU_NOTA_CN*2)+chunk.NU_NOTA_CH+(chunk.NU_NOTA_MT*3)+(chunk.NU_NOTA_LC*1.5)+(chunk.NU_NOTA_REDACAO*3))/5
		check=check+chunk.shape[0]
	else:
		chunk[chunk.TP_PRESENCA_CN == 1]
		chunk[chunk.TP_PRESENCA_CH == 1]
		chunk[chunk.TP_PRESENCA_LC == 1]
		chunk[chunk.TP_PRESENCA_MT == 1]
		chunk[chunk.TP_STATUS_REDACAO == 1]
		result=result.append(chunk)
		print("Numero de linhas  úteis, já descartadas provas eliminadas: ",chunk.shape[0])#result.shape[0])
		print("Loop ",i,"demorou %s segundos..." % (time.time() - start_time))
		i+=1
		chunk['teste']=((chunk.NU_NOTA_CN*2)+chunk.NU_NOTA_CH+(chunk.NU_NOTA_MT*3)+(chunk.NU_NOTA_LC*1.5)+(chunk.NU_NOTA_REDACAO*3))/5
		check=check+chunk.shape[0]
		
	del(chunk)    
print("Carregamento terminado... mostrando informações...")
#print(result.shape)
result.shape
print("-" * 100)
print("Mostrando 20 primeiros resultados do dataframe...")

#print(result.head(20))
result.head(20)
print("------------------------------------------------------------------------------")
print("Ordenando resultados...")
final=result.sort_values("teste", ascending=False)
print("Mostrando os 20 melhor classificados no EMEM 2016, com todas as notas inclusas")
#print(final.head(20))
final.head(20)
print("------------------------------------------------------------------------------")
print("Mostrando somente campos de interesse...")
#print(final[['NU_INSCRICAO','teste']].head(20))
print("Fim do processamento...")
final[['NU_INSCRICAO','teste']].head(20)
# Out:
# Este processador tem  4 nucleos. Uso da memória: svmem(total=8453513216, available=2237526016, percent=73.5, used=6215987200, free=2237526016)
# Iniciando leitura e filtragem dos dados...
# Cada loop lê 1 milhão de linhas do arquivo...
# ------------------------------------------------------------------------------
# Numero de linhas  úteis, já descartadas provas eliminadas:  749153
# Loop  1 demorou 7.500982046127319 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  749248
# Loop  2 demorou 14.979817152023315 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  737756
# Loop  3 demorou 22.471736907958984 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  729321
# Loop  4 demorou 30.100881814956665 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  707011
# Loop  5 demorou 37.739107608795166 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  665964
# Loop  6 demorou 45.04491877555847 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  619512
# Loop  7 demorou 52.564987659454346 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  547149
# Loop  8 demorou 60.03478240966797 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  313332
# Loop  9 demorou 69.79743266105652 segundos...
# Carregamento terminado... mostrando informações...
# (5818446, 12)
# ----------------------------------------------------------------------------------------------------
# Mostrando 20 primeiros resultados do dataframe...
#     NU_INSCRICAO  NU_NOTA_CH  NU_NOTA_CN  NU_NOTA_LC  NU_NOTA_MT  \
# 0   160000301384       629.4       550.0       574.0       462.9
# 1   160000000001       669.8       576.6       610.1       423.6
# 2   160000000002       576.9       485.8       637.4       414.6
# 3   160000000003       628.6       571.4       646.2       709.4
# 5   160000000005       537.3       556.9       585.1       708.1
# 7   160000000007       698.1       734.3       650.4       798.7
# 9   160000427445       474.6       392.4       469.9       422.5
# 10  160000427446       484.2       443.9       514.7       404.6
# 13  160000427449       582.1       460.1       585.0       551.6
# 15  160000427451       439.7       440.6       434.1       367.5
# 16  160000427452       648.1       632.7       602.5       722.5
# 18  160000427454       577.8       646.5       592.8       662.7
# 20  160000427456       626.9       610.3       594.2       509.9
# 21  160000427457       661.4       637.4       630.8       543.0
# 22  160000427458       630.2       564.1       602.3       730.6
# 25  160000427461       529.9       517.3       450.1       529.7
# 26  160000427462       544.2       446.1       500.5       599.3
# 27  160000427463       605.2       521.7       566.3       449.0
# 28  160000427464       578.7       478.2       585.4       443.6
# 30  160000427466       536.1       418.6       564.7       488.3
#
#     NU_NOTA_REDACAO  TP_PRESENCA_CH  TP_PRESENCA_CN  TP_PRESENCA_LC  \
# 38065   160000250689       789.3       790.2       706.6       905.2
# 701871  160002115771       792.8       778.3       759.1       944.1
#
#         NU_NOTA_REDACAO  TP_PRESENCA_CH  TP_PRESENCA_CN  TP_PRESENCA_LC  \
# 788160            960.0             1.0             1.0             1.0
# 45213             960.0             1.0             1.0             1.0
# 480340            980.0             1.0             1.0             1.0
# 59808             980.0             1.0             1.0             1.0
# 834649            980.0             1.0             1.0             1.0
# 778711            900.0             1.0             1.0             1.0
# 798082            900.0             1.0             1.0             1.0
# 26329             940.0             1.0             1.0             1.0
# 100215            920.0             1.0             1.0             1.0
# 920065            940.0             1.0             1.0             1.0
# 540273            980.0             1.0             1.0             1.0
# 830468            920.0             1.0             1.0             1.0
# 936807            860.0             1.0             1.0             1.0
# 486692            940.0             1.0             1.0             1.0
# 799656            880.0             1.0             1.0             1.0
# 764163            940.0             1.0             1.0             1.0
# 301658            980.0             1.0             1.0             1.0
# 857432            960.0             1.0             1.0             1.0
# 38065             980.0             1.0             1.0             1.0
# 701871            920.0             1.0             1.0             1.0
#
#         TP_PRESENCA_MT  TP_STATUS_REDACAO    teste
# 788160             1.0                1.0  1855.91
# 45213              1.0                1.0  1853.91
# 480340             1.0                1.0  1848.59
# 59808              1.0                1.0  1844.45
# 834649             1.0                1.0  1843.75
# 778711             1.0                1.0  1840.89
# 798082             1.0                1.0  1839.14
# 26329              1.0                1.0  1838.98
# 100215             1.0                1.0  1833.69
# 920065             1.0                1.0  1833.19
# 540273             1.0                1.0  1826.52
# 830468             1.0                1.0  1826.33
# 936807             1.0                1.0  1825.59
# 486692             1.0                1.0  1823.81
# 799656             1.0                1.0  1820.66
# 764163             1.0                1.0  1819.43
# 301658             1.0                1.0  1817.67
# 857432             1.0                1.0  1817.14
# 38065              1.0                1.0  1817.04
# 701871             1.0                1.0  1816.07
# ------------------------------------------------------------------------------
# Mostrando somente campos de interesse...
#         NU_INSCRICAO    teste
# 788160  160002340148  1855.91
# 45213   160000257582  1853.91
# 480340  160001169631  1848.59
# 59808   160000369220  1844.45
# 834649  160002354177  1843.75
# 778711  160002123951  1840.89
# 798082  160002333573  1839.14
# 26329   160000406496  1838.98
# 100215  160000549395  1833.69
# 920065  160000646331  1833.19
# 540273  160001963385  1826.52
# 830468  160002379239  1826.33
# 936807  160000178736  1825.59
# 486692  160001277468  1823.81
# 799656  160002377124  1820.66
# 764163  160001205527  1819.43
# 301658  160001466345  1817.67
# 857432  160001930205  1817.14
# 38065   160000250689  1817.04
# 701871  160002115771  1816.07
# Fim do processamento...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4c004110e6b1> in <module>()
#      62 print("Fim do processamento...")
#      63 final[['NU_INSCRICAO','teste']].head(20)
# ---> 64 teste
#
# NameError: name 'teste' is not defined
