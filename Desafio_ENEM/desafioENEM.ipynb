# %%
import pandas as pd
import time
import psutil
import numpy as np
import multiprocessing as mp

num_cores = mp.cpu_count()
print("Este processador tem ",num_cores,"nucleos. Uso da memória:",psutil.virtual_memory())

tamanho_bloco = 1e6 #1 milhão
start_time = time.time()
i=1
check=0
file="C:\\Users\\Martim\\Downloads\\Compressed\\microdados_enem2016\\microdados_enem_2016.csv"
indice=['NU_INSCRICAO']
colunas=['NU_INSCRICAO','TP_PRESENCA_CN','TP_PRESENCA_CH','TP_PRESENCA_LC','TP_PRESENCA_MT','NU_NOTA_CN','NU_NOTA_CH','NU_NOTA_LC','NU_NOTA_MT','TP_STATUS_REDACAO','NU_NOTA_REDACAO']
print("Iniciando leitura e filtragem dos dados... ")
print("Cada loop lê 1 milhão de linhas do arquivo...")
print("------------------------------------------------------------------------------")
for chunk in pd.read_csv(file,chunksize=tamanho_bloco,index_col=None,encoding="latin-1",usecols=colunas,delimiter=";"):
	chunk=chunk.dropna(subset=colunas)
	if(i==1):
		chunk[chunk.TP_PRESENCA_CN == 1]
		chunk[chunk.TP_PRESENCA_CH == 1]
		chunk[chunk.TP_PRESENCA_LC == 1]
		chunk[chunk.TP_PRESENCA_MT == 1]
		chunk[chunk.TP_STATUS_REDACAO == 1]
		result = chunk
		print("Numero de linhas  úteis, já descartadas provas eliminadas: ",chunk.shape[0])#result.shape[0])
		print("Loop ",i,"demorou %s segundos..." % (time.time() - start_time))
		i+=1
		chunk['teste']=((chunk.NU_NOTA_CN*2)+chunk.NU_NOTA_CH+(chunk.NU_NOTA_MT*3)+(chunk.NU_NOTA_LC*1.5)+(chunk.NU_NOTA_REDACAO*3))/5
		check=check+chunk.shape[0]
	else:
		chunk[chunk.TP_PRESENCA_CN == 1]
		chunk[chunk.TP_PRESENCA_CH == 1]
		chunk[chunk.TP_PRESENCA_LC == 1]
		chunk[chunk.TP_PRESENCA_MT == 1]
		chunk[chunk.TP_STATUS_REDACAO == 1]
		result=result.append(chunk)
		print("Numero de linhas  úteis, já descartadas provas eliminadas: ",chunk.shape[0])#result.shape[0])
		print("Loop ",i,"demorou %s segundos..." % (time.time() - start_time))
		i+=1
		chunk['teste']=((chunk.NU_NOTA_CN*2)+chunk.NU_NOTA_CH+(chunk.NU_NOTA_MT*3)+(chunk.NU_NOTA_LC*1.5)+(chunk.NU_NOTA_REDACAO*3))/5
		check=check+chunk.shape[0]
		
	del(chunk)    
print("Carregamento terminado... mostrando informações...")
#print(result.shape)
result.shape
print("-" * 100)
print("Mostrando 20 primeiros resultados do dataframe...")

#print(result.head(20))
result.head(20)
print("------------------------------------------------------------------------------")
print("Ordenando resultados...")
final=result.sort_values("teste", ascending=False)
print("Mostrando os 20 melhor classificados no EMEM 2016, com todas as notas inclusas")
#print(final.head(20))
final.head(20)
print("------------------------------------------------------------------------------")
print("Mostrando somente campos de interesse...")
#print(final[['NU_INSCRICAO','teste']].head(20))
print("Fim do processamento...")
final[['NU_INSCRICAO','teste']].head(20)
# Out:
# Este processador tem  4 nucleos. Uso da memória: svmem(total=8453513216, available=1769848832, percent=79.1, used=6683664384, free=1769848832)
# Iniciando leitura e filtragem dos dados...
# Cada loop lê 1 milhão de linhas do arquivo...
# ------------------------------------------------------------------------------
# Numero de linhas  úteis, já descartadas provas eliminadas:  749153
# Loop  1 demorou 7.749230146408081 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  749248
# Loop  2 demorou 15.665660858154297 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  737756
# Loop  3 demorou 22.744242191314697 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  729321
# Loop  4 demorou 30.051620483398438 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  707011
# Loop  5 demorou 37.549254179000854 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  665964
# Loop  6 demorou 45.92277765274048 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  619512
# Loop  7 demorou 53.48710083961487 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  547149
# Loop  8 demorou 60.99292349815369 segundos...
# Numero de linhas  úteis, já descartadas provas eliminadas:  313332
# Loop  9 demorou 65.89230060577393 segundos...
# Carregamento terminado... mostrando informações...
# ----------------------------------------------------------------------------------------------------
# Mostrando 20 primeiros resultados do dataframe...
# ------------------------------------------------------------------------------
# Ordenando resultados...
# Mostrando os 20 melhor classificados no EMEM 2016, com todas as notas inclusas
# ------------------------------------------------------------------------------
# Mostrando somente campos de interesse...
# Fim do processamento...
#         NU_INSCRICAO    teste
# 788160  160002340148  1855.91
# 45213   160000257582  1853.91
# 480340  160001169631  1848.59
# 59808   160000369220  1844.45
# 834649  160002354177  1843.75
# 778711  160002123951  1840.89
# 798082  160002333573  1839.14
# 26329   160000406496  1838.98
# 100215  160000549395  1833.69
# 920065  160000646331  1833.19
# 540273  160001963385  1826.52
# 830468  160002379239  1826.33
# 936807  160000178736  1825.59
# 486692  160001277468  1823.81
# 799656  160002377124  1820.66
# 764163  160001205527  1819.43
# 301658  160001466345  1817.67
# 857432  160001930205  1817.14
# 38065   160000250689  1817.04
# 701871  160002115771  1816.07
